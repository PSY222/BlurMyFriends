# %%
# !pip install -r requirements.txt -q
print("Installation completed.")
# Out:
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Installation completed.

# %%
# Use Code below if you don't want to see error logs
# import warnings
# import os
# import tensorflow as tf

# # Suppress TensorFlow logging
# tf.get_logger().setLevel('ERROR')
# os.environ['TF_CPP_MIN_LOG_LEVEL'] = ''
# warnings.filterwarnings('ignore')

# %%
import cv2
import spotlight 
from PIL import Image
import matplotlib.pyplot as plt

# Function to display saved output
def display_image(img):
    if isinstance(img, str): 
        img = Image.open(img)
    elif isinstance(img, np.ndarray): 
        img = Image.fromarray(img)
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %%
input_image_path = "./images/group/friends.jpg"
output_image_path = "./output/friends_jennifer_ImHere.jpeg"
reference_image_psath = "./images/target/jennifer.jpg"  
spotlight.save_image(input_image_path, output_image_path, 'ImHere',reference_image_path)
display_image(output_image_path)
# Out:
# Image saved to ./output/friends_jennifer_ImHere.jpeg

# %%
input_image_path = "./images/group/friends.jpg"
output_image_path = "./output/friends_jennifer_redArrow.jpeg"
reference_image_path = "./images/target/jennifer.jpg"  

spotlight.save_image(input_image_path, output_image_path, 'redArrow',reference_image_path)
display_image(output_image_path)
# Out:
# Image saved to ./output/friends_jennifer_redArrow.jpeg

# %%
input_image_path = "./images/group/friends.jpg"
output_image_path = "./output/friends_jennifer_bigFace.jpeg"
reference_image_path = "./images/target/jennifer.jpg"  

spotlight.save_image(input_image_path, output_image_path, 'bigface',reference_image_path)
display_image(output_image_path)
# Out:
# Image saved to ./output/friends_jennifer_bigFace.jpeg

# %%
input_image_path = "./images/group/bradgroup.jpg"
output_image_path = "./output/brad_redArrow.jpeg"
reference_image_path = "./images/target/brad.jpg"  

spotlight.save_image(input_image_path, output_image_path,'redArrow',reference_image_path)
display_image(output_image_path)
# Out:
# Image saved to ./output/brad_redArrow.jpeg
